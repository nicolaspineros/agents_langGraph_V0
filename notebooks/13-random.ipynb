# %% [markdown]
# Ejemplificamos que se puede usar un nodo aletorio pero lo ideal es modificar esto por un LLM con structured output con una tarea que indique como debe elegir el nodo a seguir segun su historial o documento

# %%
import random
nodes = ["node_1", "node_2", "node_3"]
nodes = random.sample(nodes, random.randint(1, 3))
print(nodes)
# Out:
# ['node_2']
